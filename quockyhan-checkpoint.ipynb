# %%
import turtle

p = turtle.Turtle()
p.hideturtle()
p.pensize(3)
p.speed(20)

p.penup()
p.backward(250)
p.pendown()
# lá cờ
for i in range(2):
    p.forward(500)
    p.left(90)
    p.forward(250)
    p.left(90)

p.penup()
p.left(90)
p.forward(180)
p.left(90)
p.backward(250)
p.pendown()


# trung tâm quốc kỳ
p.color('blue')
p.begin_fill()
p.circle(50)
p.end_fill()

p.penup()
p.forward(50)
p.left(90)
p.forward(50)
p.pendown()

p.color('red')
p.begin_fill()
p.circle(25,180)
p.right(180)
p.circle(25,-180)
p.left(1)
p.circle(50,180)
p.end_fill()

# ký hiệu trái trên
p.penup()
p.right(90)
p.forward(50)
p.right(90)
p.forward(30)

p.right(30)
for i in range(3):
    p.color('black')
    p.begin_fill()
    p.forward(60)
    p.left(90)
    p.forward(10)
    p.left(90)
    p.forward(60)
    p.left(90)
    p.forward(10)
    p.left(90)
    p.end_fill()
    p.penup()
    p.left(90)
    p.forward(20)
    p.right(90)
    p.pendown()

# bang trái dưới
p.penup()
p.right(145)
p.forward(110)
p.left(30)
p.pendown()
# thanh ngoài cùng
p.color('black')
p.begin_fill()
p.forward(60)
p.left(90)
p.forward(10)
p.left(90)
p.forward(60)
p.left(10)
p.end_fill()

p.penup()
p.right(90)
p.forward(10)
p.right(100)
p.pendown()
#thanh giữa
p.color('black')
p.begin_fill()
p.forward(25)
p.left(90)
p.forward(10)
p.left(90)
p.forward(25)
p.left(10)
p.end_fill()

p.penup()
p.left(170)
p.forward(35)
p.pendown()

p.color('black')
p.begin_fill()
p.forward(25)
p.right(90)
p.forward(10)
p.right(90)
p.forward(25)
p.right(10)
p.end_fill()

p.penup()
p.forward(35)
p.right(90)
p.forward(15)
p.right(80)
p.pendown()
#thanh trong cùng
p.color('black')
p.begin_fill()
p.forward(60)
p.left(90)
p.forward(10)
p.left(90)
p.forward(60)
p.left(10)
p.end_fill()

# ban phải dưới
p.penup()
p.right(135)
p.forward(200)
p.right(130)
p.pendown()
#thanh trong cùng
p.color('black')
p.begin_fill()
p.forward(25)
p.left(90)
p.forward(10)
p.left(90)
p.forward(25)
p.left(10)
p.end_fill()

p.penup()
p.left(170)
p.forward(35)
p.pendown()

p.color('black')
p.begin_fill()
p.forward(25)
p.right(90)
p.forward(10)
p.right(90)
p.forward(25)
p.right(10)
p.end_fill()

#cách
p.penup()
p.forward(40)
p.right(90)
p.forward(15)
p.right(80)
p.pendown()

#thanh giữa
p.color('black')
p.begin_fill()
p.forward(25)
p.left(90)
p.forward(10)
p.left(90)
p.forward(25)
p.left(10)
p.end_fill()

p.penup()
p.left(170)
p.forward(35)
p.pendown()

p.color('black')
p.begin_fill()
p.forward(25)
p.right(90)
p.forward(10)
p.right(90)
p.forward(25)
p.right(10)
p.end_fill()

#cách
p.penup()
p.forward(40)
p.right(90)
p.forward(15)
p.right(80)
p.pendown()

#thanh ngoài cùng
p.color('black')
p.begin_fill()
p.forward(25)
p.left(90)
p.forward(10)
p.left(90)
p.forward(25)
p.left(10)
p.end_fill()

p.penup()
p.left(170)
p.forward(35)
p.pendown()

p.color('black')
p.begin_fill()
p.forward(25)
p.right(90)
p.forward(10)
p.right(90)
p.forward(25)
p.right(10)
p.end_fill()

#bang phải trên
p.penup()
p.left(45)
p.forward(110)
p.left(45)
p.pendown()

#thanh trong cùng
p.color('black')
p.begin_fill()
p.forward(25)
p.left(90)
p.forward(10)
p.left(90)
p.forward(25)
p.left(10)
p.end_fill()

p.penup()
p.left(170)
p.forward(35)
p.pendown()

p.color('black')
p.begin_fill()
p.forward(25)
p.right(90)
p.forward(10)
p.right(90)
p.forward(25)
p.right(10)
p.end_fill()

#cách
p.penup()
p.forward(50)
p.left(135)
p.forward(25)
p.left(55)
p.pendown()

#thanh giữa
p.color('black')
p.begin_fill()
p.forward(60)
p.right(90)
p.forward(10)
p.right(90)
p.forward(60)
p.right(90)
p.forward(10)
p.right(90)
p.end_fill()


#cách
p.penup()
p.right(90)
p.forward(30)
p.left(90)
p.pendown()

#thanh ngoài cùng
p.color('black')
p.begin_fill()
p.forward(25)
p.left(90)
p.forward(10)
p.left(90)
p.forward(25)
p.left(10)
p.end_fill()

p.penup()
p.left(170)
p.forward(35)
p.pendown()

p.color('black')
p.begin_fill()
p.forward(25)
p.right(90)
p.forward(10)
p.right(90)
p.forward(25)
p.right(10)
p.end_fill()


turtle.done()
